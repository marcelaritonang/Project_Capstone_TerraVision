# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from keras_tuner import Hyperband

# %%
# Memuat dataset
url = '/kaggle/input/sdfgbffasdf/Modified_DatasetCapstoneRianco.csv'
df = pd.read_csv(url)
print(df.shape)
print(df.head())
# Out:
# (12163, 6)
#     HARGA     LT     LB   JKT  JKM     Kota
# 0  2100.0  137.0  170.0   3.0  2.0  Bandung
# 1  4100.0  202.0  300.0   3.0  2.0  Bandung
# 2  3300.0  350.0  258.0   5.0  2.0  Bandung
# 3   580.0   30.0   80.0   2.0  2.0  Bandung
# 4  1300.0  176.0  176.0  11.0  3.0  Bandung

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12163 entries, 0 to 12162
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HARGA   12163 non-null  float64
#  1   LT      12161 non-null  float64
#  2   LB      12161 non-null  float64
#  3   JKT     12129 non-null  float64
#  4   JKM     12134 non-null  float64
#  5   Kota    12163 non-null  object
# dtypes: float64(5), object(1)
# memory usage: 570.3+ KB

# %%
# Cek missing value
print(df.isnull().sum())
# Out:
# HARGA     0
# LT        2
# LB        2
# JKT      34
# JKM      29
# Kota      0
# dtype: int64

# %%
df['Kota'] = df['Kota'].replace('JAKSEL', 'Jakarta Selatan')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12163 entries, 0 to 12162
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HARGA   12163 non-null  float64
#  1   LT      12161 non-null  float64
#  2   LB      12161 non-null  float64
#  3   JKT     12129 non-null  float64
#  4   JKM     12134 non-null  float64
#  5   Kota    12163 non-null  object
# dtypes: float64(5), object(1)
# memory usage: 570.3+ KB

# %%
df.loc[df['HARGA'] < 300, 'HARGA'] *= 100

# %%
df.nsmallest(20,"HARGA")
# Out:
#        HARGA     LT     LB  JKT  JKM     Kota
# 230    300.0  140.0  100.0  4.0  3.0  Bandung
# 2405   300.0   55.0   40.0  2.0  1.0  Bandung
# 3118   300.0   55.0   40.0  2.0  1.0  Bandung
# 3374   300.0   67.0   31.0  2.0  1.0  Bandung
# 3428   300.0   72.0   36.0  2.0  1.0  Bandung
# 3497   300.0   67.0   31.0  2.0  1.0  Bandung
# 3619   300.0   60.0   30.0  2.0  1.0  Bandung
# 3642   300.0   60.0   40.0  2.0  1.0  Bandung
# 6584   300.0   37.0   60.0  5.0  4.0  Bandung
# 7091   300.0   60.0   40.0  2.0  1.0  Bandung
# 8640   300.0   60.0   36.0  2.0  1.0   Bekasi
# 8667   300.0   70.0   70.0  2.0  2.0   Bekasi
# 8674   300.0   60.0   36.0  2.0  1.0   Bekasi
# 9062   300.0   60.0   36.0  2.0  1.0   Bekasi
# 9069   300.0   52.0   45.0  2.0  1.0   Bekasi
# 9481   300.0   60.0   36.0  2.0  1.0    Bogor
# 9924   300.0   72.0   60.0  2.0  1.0    Bogor
# 9929   300.0   72.0   45.0  3.0  1.0    Bogor
# 9970   300.0   84.0   42.0  2.0  1.0    Bogor
# 10030  300.0   72.0   50.0  2.0  1.0    Bogor

# %%
# Menghapus baris dengan nilai NaN yang mungkin muncul setelah konversi
df = df.dropna(subset=['HARGA'])

# Menghapus nilai di atas 100,000
df = df[df['HARGA'] <= 80000]

# %%
df.nlargest(30,'HARGA')
# Out:
#          HARGA      LT      LB   JKT   JKM             Kota
# 6947   80000.0  2000.0   400.0   5.0   5.0          Bandung
# 8408   80000.0   800.0  2000.0   7.0   6.0  Jakarta Selatan
# 4454   79500.0  2122.0   901.0  23.0  10.0          Bandung
# 4455   79500.0  2122.0   901.0  23.0  10.0          Bandung
# 4218   78500.0  2000.0   600.0   7.0   4.0          Bandung
# 8585   77500.0  1148.0  1200.0   8.0   6.0  Jakarta Selatan
# 1841   77000.0  2200.0  1000.0   7.0   5.0          Bandung
# 1732   75000.0  4550.0   300.0   5.0   3.0          Bandung
# 2006   75000.0   712.0   400.0   5.0   3.0          Bandung
# 6940   75000.0  2000.0  2000.0   2.0   2.0          Bandung
# 8098   75000.0  1830.0  1000.0   5.0   4.0  Jakarta Selatan
# 8444   75000.0  1050.0  1500.0   5.0   5.0  Jakarta Selatan
# 8471   75000.0  3000.0  2000.0   4.0   4.0  Jakarta Selatan
# 8468   72000.0   855.0   589.0   5.0   3.0  Jakarta Selatan
# 11272  70000.0   680.0  1200.0   5.0   5.0  Jakarta Selatan
# 11030  69000.0   474.0  1200.0   4.0   5.0    Jakarta Pusat
# 11031  69000.0   475.0  1200.0   4.0   4.0    Jakarta Pusat
# 7640   68000.0   470.0  1000.0   5.0   5.0  Jakarta Selatan
# 8050   68000.0  2595.0  1000.0   5.0   5.0  Jakarta Selatan
# 8445   68000.0   470.0  1000.0   5.0   5.0  Jakarta Selatan
# 8560   68000.0   814.0   494.0   5.0   5.0  Jakarta Selatan
# 8454   65000.0   586.0   600.0   5.0   4.0  Jakarta Selatan
# 8598   65000.0   472.0  1200.0   5.0   5.0  Jakarta Selatan
# 10666  63000.0  5250.0   200.0   4.0   3.0  Jakarta Selatan
# 3743   62000.0  1561.0  1200.0  10.0  11.0          Bandung
# 4271   60500.0  1345.0  1000.0   7.0   5.0          Bandung
# 1872   60000.0  1791.0   300.0   4.0   3.0          Bandung
# 6841   60000.0  1791.0   179.0   5.0   4.0          Bandung
# 6939   60000.0  1464.0   700.0   7.0   5.0          Bandung
# 7837   60000.0  1500.0  1200.0   6.0   6.0  Jakarta Selatan

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import keras_tuner as kt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Gantikan 'data' dengan 'df'
df = df.dropna()  # Menghapus baris dengan nilai NaN
label_encoder = LabelEncoder()
df['Kota'] = label_encoder.fit_transform(df['Kota'])

# Feature Engineering
df['LT_LB'] = df['LT'] * df['LB']
df['Log_LT'] = np.log1p(df['LT'])
df['Log_LB'] = np.log1p(df['LB'])

# Ensure LT and LB are one-dimensional and do not contain NaN values
if df['LT'].isnull().any() or df['LB'].isnull().any():
    raise ValueError("LT and LB must not contain NaN values")
if df['LT'].ndim != 1 or df['LB'].ndim != 1:
    raise ValueError("LT and LB must be 1 dimensional")

# Binning Continuous Variables
df['LT_bin'] = pd.cut(df['LT'], bins=[0, 100, 200, 300, 400, np.inf], labels=['0-100', '100-200', '200-300', '300-400', '400+'])
df['LB_bin'] = pd.cut(df['LB'], bins=[0, 50, 100, 150, 200, np.inf], labels=['0-50', '50-100', '100-150', '150-200', '200+'])

# One-hot Encoding
df = pd.get_dummies(df, columns=['Kota', 'LT_bin', 'LB_bin'])

X = df.drop(columns=['HARGA'])
y = df['HARGA']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')  # atau 'mean'
df[['LT', 'LB', 'JKT', 'JKM']] = imputer.fit_transform(df[['LT', 'LB', 'JKT', 'JKM']])

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(keras.layers.Input(shape=(X_train_scaled.shape[1],)))

    # Tune the number of units in the first Dense layer
    hp_units1 = hp.Int('units1', min_value=32, max_value=512, step=32)
    model.add(keras.layers.Dense(units=hp_units1, activation='relu'))
  
    # Tune dropout rate
    hp_dropout1 = hp.Float('dropout1', min_value=0.0, max_value=0.5, step=0.1)
    model.add(keras.layers.Dropout(rate=hp_dropout1))

    # Additional layers with tunable units
    hp_units2 = hp.Int('units2', min_value=32, max_value=256, step=32)
    model.add(keras.layers.Dense(units=hp_units2, activation='relu'))

    hp_units3 = hp.Int('units3', min_value=16, max_value=128, step=16)
    model.add(keras.layers.Dense(units=hp_units3, activation='relu'))

    hp_dropout2 = hp.Float('dropout2', min_value=0.0, max_value=0.5, step=0.1)
    model.add(keras.layers.Dropout(rate=hp_dropout2))

    model.add(keras.layers.Dense(1, activation='linear'))

    # Tune the learning rate for the optimizer
    hp_learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='mean_squared_error',
                  metrics=['mean_absolute_error'])

    return model

# %%
from tensorflow import keras
import keras_tuner as kt
tuner = kt.RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=10,
    executions_per_trial=1,
    directory='my_dir1',
    project_name='intro_to_kt'
)

tuner.search(X_train_scaled, y_train, epochs=40, validation_split=0.2)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The optimal number of units in the first densely-connected layer is {best_hps.get('units1')}.
The optimal number of units in the second densely-connected layer is {best_hps.get('units2')}.
The optimal number of units in the third densely-connected layer is {best_hps.get('units3')}.
The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
The optimal dropout rate for the first dropout layer is {best_hps.get('dropout1')}.
The optimal dropout rate for the second dropout layer is {best_hps.get('dropout2')}.
""")
# Out:
# Reloading Tuner from my_dir1/intro_to_kt/tuner0.json
#
# The optimal number of units in the first densely-connected layer is 288.
# The optimal number of units in the second densely-connected layer is 224.
# The optimal number of units in the third densely-connected layer is 96.
# The optimal learning rate for the optimizer is 0.0025000464748982493.
# The optimal dropout rate for the first dropout layer is 0.2.
# The optimal dropout rate for the second dropout layer is 0.4.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2

# Buat model dengan regularisasi L2
model = Sequential([
    tf.keras.layers.Input(shape=(X_train_scaled.shape[1],)),
    Dense(288, activation='relu', kernel_regularizer=l2(0.001)),  # Menambahkan regularisasi L2
    Dropout(0.2),
    Dense(224, activation='relu', kernel_regularizer=l2(0.001)),  # Menambahkan regularisasi L2
    Dense(96, activation='relu', kernel_regularizer=l2(0.001)),   # Menambahkan regularisasi L2
    Dropout(0.4),
    Dense(1, activation='linear')
])

# %%
# Kompilasi model
# Menggunakan learning rate optimal
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0025),
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])

# Latih model dengan tensor input yang sudah di-encode
history = model.fit(X_train_scaled, y_train, batch_size=32 ,epochs=100,validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 61721804.0000 - mean_absolute_error: 3783.5039 - val_loss: 138156112.0000 - val_mean_absolute_error: 3163.9883
# Epoch 2/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32317162.0000 - mean_absolute_error: 2756.9202 - val_loss: 203748176.0000 - val_mean_absolute_error: 2846.7507
# Epoch 3/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31476422.0000 - mean_absolute_error: 2641.5466 - val_loss: 255261856.0000 - val_mean_absolute_error: 2906.4104
# Epoch 4/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27638474.0000 - mean_absolute_error: 2541.0083 - val_loss: 294433984.0000 - val_mean_absolute_error: 3122.7336
# Epoch 5/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28972788.0000 - mean_absolute_error: 2633.7117 - val_loss: 298934912.0000 - val_mean_absolute_error: 2837.2751
# Epoch 6/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26370806.0000 - mean_absolute_error: 2462.8391 - val_loss: 393873728.0000 - val_mean_absolute_error: 3078.4951
# Epoch 7/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28764676.0000 - mean_absolute_error: 2620.4695 - val_loss: 375284320.0000 - val_mean_absolute_error: 2936.4077
# Epoch 8/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 30954184.0000 - mean_absolute_error: 2645.8918 - val_loss: 400939296.0000 - val_mean_absolute_error: 2900.9983
# Epoch 9/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26967600.0000 - mean_absolute_error: 2500.8669 - val_loss: 370356608.0000 - val_mean_absolute_error: 2836.4905
# Epoch 10/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 30326522.0000 - mean_absolute_error: 2604.6370 - val_loss: 431889440.0000 - val_mean_absolute_error: 2905.8699
# Epoch 11/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27430956.0000 - mean_absolute_error: 2477.3176 - val_loss: 324993184.0000 - val_mean_absolute_error: 2851.7214
# Epoch 12/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27331266.0000 - mean_absolute_error: 2495.9202 - val_loss: 374225856.0000 - val_mean_absolute_error: 2972.2175
# Epoch 13/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27272052.0000 - mean_absolute_error: 2527.3923 - val_loss: 259229984.0000 - val_mean_absolute_error: 2792.6658
# Epoch 14/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27867236.0000 - mean_absolute_error: 2537.3892 - val_loss: 321469312.0000 - val_mean_absolute_error: 2888.7764
# Epoch 15/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26074836.0000 - mean_absolute_error: 2482.2788 - val_loss: 312453056.0000 - val_mean_absolute_error: 2901.5410
# Epoch 16/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26152396.0000 - mean_absolute_error: 2463.3267 - val_loss: 286670720.0000 - val_mean_absolute_error: 2835.5471
# Epoch 17/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28309380.0000 - mean_absolute_error: 2578.5718 - val_loss: 344596672.0000 - val_mean_absolute_error: 2978.8767
# Epoch 18/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26214706.0000 - mean_absolute_error: 2431.2126 - val_loss: 282707136.0000 - val_mean_absolute_error: 2733.6870
# Epoch 19/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28757616.0000 - mean_absolute_error: 2581.0718 - val_loss: 323233888.0000 - val_mean_absolute_error: 2705.6970
# Epoch 20/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25368884.0000 - mean_absolute_error: 2465.7419 - val_loss: 420484032.0000 - val_mean_absolute_error: 2929.4644
# Epoch 21/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29863550.0000 - mean_absolute_error: 2574.0928 - val_loss: 328186912.0000 - val_mean_absolute_error: 2715.4885
# Epoch 22/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26740592.0000 - mean_absolute_error: 2485.6707 - val_loss: 327433984.0000 - val_mean_absolute_error: 2863.7847
# Epoch 23/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28007336.0000 - mean_absolute_error: 2520.3879 - val_loss: 364790816.0000 - val_mean_absolute_error: 2791.4402
# Epoch 24/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28110236.0000 - mean_absolute_error: 2505.4492 - val_loss: 433751040.0000 - val_mean_absolute_error: 2923.7346
# Epoch 25/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27841212.0000 - mean_absolute_error: 2515.1470 - val_loss: 411935744.0000 - val_mean_absolute_error: 2686.1853
# Epoch 26/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28296296.0000 - mean_absolute_error: 2477.0122 - val_loss: 447925920.0000 - val_mean_absolute_error: 2842.4578
# Epoch 27/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27156296.0000 - mean_absolute_error: 2476.8398 - val_loss: 530459008.0000 - val_mean_absolute_error: 2901.3152
# Epoch 28/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26035554.0000 - mean_absolute_error: 2422.4468 - val_loss: 504632672.0000 - val_mean_absolute_error: 2914.9622
# Epoch 29/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25959962.0000 - mean_absolute_error: 2448.4062 - val_loss: 457620800.0000 - val_mean_absolute_error: 2779.8022
# Epoch 30/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26594988.0000 - mean_absolute_error: 2465.1135 - val_loss: 491733856.0000 - val_mean_absolute_error: 2789.8579
# Epoch 31/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28834408.0000 - mean_absolute_error: 2473.8821 - val_loss: 510151200.0000 - val_mean_absolute_error: 2783.6301
# Epoch 32/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26297620.0000 - mean_absolute_error: 2459.3564 - val_loss: 647505024.0000 - val_mean_absolute_error: 3105.7419
# Epoch 33/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27639894.0000 - mean_absolute_error: 2502.9949 - val_loss: 574932160.0000 - val_mean_absolute_error: 2814.1726
# Epoch 34/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26845218.0000 - mean_absolute_error: 2405.0637 - val_loss: 566529152.0000 - val_mean_absolute_error: 2780.7410
# Epoch 35/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27996658.0000 - mean_absolute_error: 2490.9290 - val_loss: 593166336.0000 - val_mean_absolute_error: 2890.6978
# Epoch 36/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25687448.0000 - mean_absolute_error: 2403.6511 - val_loss: 601586624.0000 - val_mean_absolute_error: 2753.5117
# Epoch 37/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 24517772.0000 - mean_absolute_error: 2305.4622 - val_loss: 618565504.0000 - val_mean_absolute_error: 2833.7688
# Epoch 38/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26761338.0000 - mean_absolute_error: 2450.2891 - val_loss: 699219968.0000 - val_mean_absolute_error: 2905.4922
# Epoch 39/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25876082.0000 - mean_absolute_error: 2446.4556 - val_loss: 663320384.0000 - val_mean_absolute_error: 2777.5171
# Epoch 40/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 29072780.0000 - mean_absolute_error: 2462.6765 - val_loss: 669469248.0000 - val_mean_absolute_error: 2863.0005
# Epoch 41/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28098644.0000 - mean_absolute_error: 2452.0845 - val_loss: 622093248.0000 - val_mean_absolute_error: 2829.8853
# Epoch 42/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26831054.0000 - mean_absolute_error: 2393.0225 - val_loss: 556586432.0000 - val_mean_absolute_error: 2783.2827
# Epoch 43/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27696090.0000 - mean_absolute_error: 2462.5986 - val_loss: 647801664.0000 - val_mean_absolute_error: 2842.7681
# Epoch 44/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27044402.0000 - mean_absolute_error: 2447.7832 - val_loss: 639617472.0000 - val_mean_absolute_error: 2844.0051
# Epoch 45/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25250500.0000 - mean_absolute_error: 2320.2888 - val_loss: 559995200.0000 - val_mean_absolute_error: 2877.5750
# Epoch 46/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25592860.0000 - mean_absolute_error: 2397.1748 - val_loss: 650128256.0000 - val_mean_absolute_error: 2833.2056
# Epoch 47/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25056306.0000 - mean_absolute_error: 2376.0693 - val_loss: 481586880.0000 - val_mean_absolute_error: 2802.8306
# Epoch 48/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28035846.0000 - mean_absolute_error: 2448.0344 - val_loss: 583231680.0000 - val_mean_absolute_error: 2783.5090
# Epoch 49/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26744244.0000 - mean_absolute_error: 2392.2231 - val_loss: 555687168.0000 - val_mean_absolute_error: 2803.6545
# Epoch 50/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26950222.0000 - mean_absolute_error: 2450.1282 - val_loss: 500752480.0000 - val_mean_absolute_error: 2761.7429
# Epoch 51/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24193706.0000 - mean_absolute_error: 2324.4985 - val_loss: 515093184.0000 - val_mean_absolute_error: 2799.2153
# Epoch 52/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 24452026.0000 - mean_absolute_error: 2330.5259 - val_loss: 505730080.0000 - val_mean_absolute_error: 2743.6794
# Epoch 53/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 29304116.0000 - mean_absolute_error: 2500.1489 - val_loss: 513300928.0000 - val_mean_absolute_error: 2740.2783
# Epoch 54/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29362080.0000 - mean_absolute_error: 2466.2578 - val_loss: 512113856.0000 - val_mean_absolute_error: 2871.4045
# Epoch 55/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25939518.0000 - mean_absolute_error: 2366.8518 - val_loss: 480105152.0000 - val_mean_absolute_error: 2880.6143
# Epoch 56/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26739932.0000 - mean_absolute_error: 2448.3611 - val_loss: 458099616.0000 - val_mean_absolute_error: 2740.8467
# Epoch 57/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26566048.0000 - mean_absolute_error: 2392.5964 - val_loss: 432232096.0000 - val_mean_absolute_error: 2673.0396
# Epoch 58/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25591374.0000 - mean_absolute_error: 2380.4097 - val_loss: 457203360.0000 - val_mean_absolute_error: 2782.7803
# Epoch 59/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22863428.0000 - mean_absolute_error: 2219.3259 - val_loss: 505482720.0000 - val_mean_absolute_error: 2784.0613
# Epoch 60/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26704170.0000 - mean_absolute_error: 2371.7769 - val_loss: 415442272.0000 - val_mean_absolute_error: 2707.0354
# Epoch 61/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25992358.0000 - mean_absolute_error: 2404.5950 - val_loss: 486333376.0000 - val_mean_absolute_error: 2794.5417
# Epoch 62/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25308968.0000 - mean_absolute_error: 2341.2173 - val_loss: 509980736.0000 - val_mean_absolute_error: 2754.5034
# Epoch 63/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25180546.0000 - mean_absolute_error: 2409.5981 - val_loss: 529421216.0000 - val_mean_absolute_error: 2775.9766
# Epoch 64/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26923126.0000 - mean_absolute_error: 2349.4807 - val_loss: 551854464.0000 - val_mean_absolute_error: 2735.7810
# Epoch 65/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26191774.0000 - mean_absolute_error: 2341.5898 - val_loss: 507851936.0000 - val_mean_absolute_error: 2768.3643
# Epoch 66/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 23774098.0000 - mean_absolute_error: 2327.5190 - val_loss: 464322528.0000 - val_mean_absolute_error: 2731.3943
# Epoch 67/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25337260.0000 - mean_absolute_error: 2327.2974 - val_loss: 530167872.0000 - val_mean_absolute_error: 2884.2366
# Epoch 68/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26030906.0000 - mean_absolute_error: 2380.8120 - val_loss: 556686592.0000 - val_mean_absolute_error: 2968.6587
# Epoch 69/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 24049464.0000 - mean_absolute_error: 2345.3267 - val_loss: 586740608.0000 - val_mean_absolute_error: 2865.2664
# Epoch 70/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 23844490.0000 - mean_absolute_error: 2299.8760 - val_loss: 624788480.0000 - val_mean_absolute_error: 2835.8774
# Epoch 71/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23331396.0000 - mean_absolute_error: 2235.0837 - val_loss: 556442880.0000 - val_mean_absolute_error: 2868.9077
# Epoch 72/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23625884.0000 - mean_absolute_error: 2315.0991 - val_loss: 597483072.0000 - val_mean_absolute_error: 2787.4150
# Epoch 73/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26535746.0000 - mean_absolute_error: 2359.0918 - val_loss: 704331456.0000 - val_mean_absolute_error: 2941.7769
# Epoch 74/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 24767962.0000 - mean_absolute_error: 2349.3901 - val_loss: 508955552.0000 - val_mean_absolute_error: 2703.6045
# Epoch 75/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26438562.0000 - mean_absolute_error: 2306.8367 - val_loss: 398115840.0000 - val_mean_absolute_error: 2680.2197
# Epoch 76/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24955350.0000 - mean_absolute_error: 2297.9688 - val_loss: 548512896.0000 - val_mean_absolute_error: 2734.6223
# Epoch 77/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 25989496.0000 - mean_absolute_error: 2334.1978 - val_loss: 607620992.0000 - val_mean_absolute_error: 2912.4648
# Epoch 78/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26285168.0000 - mean_absolute_error: 2358.0627 - val_loss: 731747392.0000 - val_mean_absolute_error: 3001.9575
# Epoch 79/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 27119600.0000 - mean_absolute_error: 2378.8875 - val_loss: 558077120.0000 - val_mean_absolute_error: 2739.7742
# Epoch 80/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24788132.0000 - mean_absolute_error: 2319.7163 - val_loss: 665660672.0000 - val_mean_absolute_error: 2983.0928
# Epoch 81/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24153504.0000 - mean_absolute_error: 2334.1418 - val_loss: 539655232.0000 - val_mean_absolute_error: 2780.6421
# Epoch 82/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27386610.0000 - mean_absolute_error: 2399.1682 - val_loss: 558935168.0000 - val_mean_absolute_error: 2842.0562
# Epoch 83/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26699708.0000 - mean_absolute_error: 2421.9966 - val_loss: 557150528.0000 - val_mean_absolute_error: 2768.7571
# Epoch 84/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 23068416.0000 - mean_absolute_error: 2291.4199 - val_loss: 628790272.0000 - val_mean_absolute_error: 2749.3213
# Epoch 85/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25218362.0000 - mean_absolute_error: 2326.0610 - val_loss: 726758208.0000 - val_mean_absolute_error: 2994.5667
# Epoch 86/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24136118.0000 - mean_absolute_error: 2338.3220 - val_loss: 785372672.0000 - val_mean_absolute_error: 2924.6777
# Epoch 87/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22835940.0000 - mean_absolute_error: 2270.0286 - val_loss: 714721152.0000 - val_mean_absolute_error: 2905.7520
# Epoch 88/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 26045242.0000 - mean_absolute_error: 2397.4050 - val_loss: 590396288.0000 - val_mean_absolute_error: 2729.0884
# Epoch 89/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23895814.0000 - mean_absolute_error: 2278.0061 - val_loss: 561735168.0000 - val_mean_absolute_error: 2700.3889
# Epoch 90/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25244038.0000 - mean_absolute_error: 2340.6875 - val_loss: 536738048.0000 - val_mean_absolute_error: 2683.2542
# Epoch 91/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24715616.0000 - mean_absolute_error: 2332.2222 - val_loss: 550235712.0000 - val_mean_absolute_error: 2718.5610
# Epoch 92/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24957110.0000 - mean_absolute_error: 2285.0181 - val_loss: 662646080.0000 - val_mean_absolute_error: 2773.9163
# Epoch 93/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24705936.0000 - mean_absolute_error: 2333.7969 - val_loss: 749611648.0000 - val_mean_absolute_error: 2852.2859
# Epoch 94/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26487442.0000 - mean_absolute_error: 2357.3582 - val_loss: 557451072.0000 - val_mean_absolute_error: 2902.9822
# Epoch 95/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26010380.0000 - mean_absolute_error: 2357.3130 - val_loss: 505522368.0000 - val_mean_absolute_error: 2814.7769
# Epoch 96/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24388754.0000 - mean_absolute_error: 2323.3064 - val_loss: 600675840.0000 - val_mean_absolute_error: 2789.4600
# Epoch 97/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 24782380.0000 - mean_absolute_error: 2350.6099 - val_loss: 596826496.0000 - val_mean_absolute_error: 2733.9265
# Epoch 98/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 23884714.0000 - mean_absolute_error: 2254.7744 - val_loss: 619205824.0000 - val_mean_absolute_error: 2838.8145
# Epoch 99/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 24612752.0000 - mean_absolute_error: 2333.1042 - val_loss: 582632832.0000 - val_mean_absolute_error: 2742.8533
# Epoch 100/100
# 303/303 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26423062.0000 - mean_absolute_error: 2400.3269 - val_loss: 678001408.0000 - val_mean_absolute_error: 2783.1143

# %%
# Creating a dictionary to see the mapping of city names to their encoded values
kota_labels = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(kota_labels)
# Out:
# {'Bandung': 0, 'Bekasi': 1, 'Bogor': 2, 'Depok': 3, 'Jakarta Barat': 4, 'Jakarta Pusat': 5, 'Jakarta Selatan': 6, 'Jakarta Timur': 7, 'Jakarta Utara': 8, 'Tangerang': 9}

# %%
# Prediksi pada data uji
y_pred = model.predict(X_test_scaled)

# Cetak nilai aktual dan prediksi untuk beberapa sampel pertama
for actual, predicted in zip(y_test[:10], y_pred.flatten()[:10]):
    print(f"Actual: {actual}, Predicted: {predicted:.2f}")
    
    # Hitung Mean Squared Error (MSE)
mae = mean_absolute_error(y_test, y_pred)

print("MaE on Test Data:", mae)
# Out:
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Actual: 2000.0, Predicted: 2757.29
# Actual: 2700.0, Predicted: 1987.67
# Actual: 1200.0, Predicted: 1267.10
# Actual: 3250.0, Predicted: 2791.04
# Actual: 2300.0, Predicted: 1323.31
# Actual: 5900.0, Predicted: 6005.57
# Actual: 1350.0, Predicted: 1350.06
# Actual: 1450.0, Predicted: 1051.21
# Actual: 1090.0, Predicted: 1376.56
# Actual: 3900.0, Predicted: 9217.47
# MaE on Test Data: 2783.11502118089

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np
# Menghitung nilai rata-rata target dari set latih
mean_y_train = np.mean(y_train)

# Membuat array prediksi yang berisi nilai rata-rata untuk setiap sampel di set uji
baseline_predictions = np.full(shape=y_test.shape, fill_value=mean_y_train)

# Menghitung MAE antara prediksi baseline dan nilai sebenarnya di set uji
baseline_mae = mean_absolute_error(y_test, baseline_predictions)
print("Baseline MAE:", baseline_mae)
# Out:
# Baseline MAE: 5274.020274931766

# %%
# Anggap 'model' adalah model Keras yang sudah dilatih dan siap
model.save("my_modelLastTTT.h5")

# %%
import tensorflow as tf

# Load the pre-trained Keras model
model = tf.keras.models.load_model("/kaggle/working/my_modelLastTTT.h5")

# Create a TFLiteConverter object from the loaded Keras model
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Set optimization strategy if needed, here using default optimizations
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model
tflite_model = converter.convert()

# Save the TFLite model to the Kaggle working directory
tflite_path = '/kaggle/working/model.tflite'
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

# Print the path for reference
print("Model saved to:", tflite_path)
